# %% [markdown]
# ## Project: PCA and tSNE
#  **Marks: 30**
# -----------------------------
#
# Welcome to the project on PCA and tSNE. In this project. We will be using the auto-mpg dataset.
#
# -----------------------------
# ## Objective:
# -----------------------------
# The objective of this problem is to explore the data and reduce the number of features by using dimensionality reduction techniques like PCA and TSNE and generate meaningful insights.
#
# -----------------------------
# ## Dataset:
# -----------------------------
# There are 8 variables in the data:
#
# - mpg: miles per gallon
# - cyl: number of cylinders
# - disp: engine displacement (cu. inches) or engine size
# - hp: horsepower
# - wt: vehicle weight (lbs.)
# - acc: time taken to accelerate from O to 60 mph (sec.)
# - yr: model year
# - car name: car model name

# %% [markdown]
# ## Importing necessary libraries and overview of the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#to scale the data using z-score 
from sklearn.preprocessing import StandardScaler

#importing PCA and TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# #### Loading data

# %%
data = pd.read_csv("auto-mpg.csv")

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#                     car name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# #### Check the info of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   car name      398 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 25.0+ KB

# %% [markdown]
# **Observations:**
#
# - There are 398 observations and 8 columns in the data.
# - All variables except horsepower and car name are of numeric data type.
# - The horsepower must be a numeric data type. We will explore this further.

# %% [markdown]
# ## Data Preprocessing and Exploratory Data Analysis

# %%
data["car name"].nunique()
# Out:
# 305

# %% [markdown]
# - The column 'car name' is of object data type containing a lot of unique entries and would not add values to our analysis. We can drop this column.

# %%
# dropping car_name
data1 = data.copy()
data = data.drop(['car name'], axis=1)

# %% [markdown]
# #### Checking values in horsepower column

# %%
# checking if there are values other than digits in the column 'horsepower' 
hpIsDigit = pd.DataFrame(data.horsepower.str.isdigit())  # if the string is made of digits store True else False

# print isDigit = False!
data[hpIsDigit['horsepower'] == False]   # from temp take only those rows where hp has false
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year
# 32           71
# 126          74
# 330          80
# 336          80
# 354          81
# 374          82

# %% [markdown]
# **Observations:**
# - There are 6 observations where horsepower is ?.
# - We can consider these values as missing values.
# - Let's impute these missing values and change the data type of horsepower column.
# - First we need to replace the ? with np.nan.

# %%
#Relacing ? with np.nan
data = data.replace('?', np.nan)
data[hpIsDigit['horsepower'] == False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0        NaN    2046          19.0
# 126  21.0          6         200.0        NaN    2875          17.0
# 330  40.9          4          85.0        NaN    1835          17.3
# 336  23.6          4         140.0        NaN    2905          14.3
# 354  34.5          4         100.0        NaN    2320          15.8
# 374  23.0          4         151.0        NaN    3035          20.5
#
#      model year
# 32           71
# 126          74
# 330          80
# 336          80
# 354          81
# 374          82

# %%
# Imputing the missing values with median value
data.horsepower.fillna(data.horsepower.median(), inplace=True)
data['horsepower'] = data['horsepower'].astype('float64')  # converting the hp column from object data type to float

# %% [markdown]
# #### Summary Statistics

# %% [markdown]
# #### Question 1:
# - **Check the summary statistics of the data (use describe function) (1 Mark)**
# - **Write your observations (1 Mark)**

# %%
#Write your code here
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.304020  2970.424623
# std      7.815984    1.701004    104.269838   38.222625   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **Observations:________**
#
# All dimensions have no missing data and are numeric. The max and min values appear to be typical and no noticeable discrepancies.

# %% [markdown]
# #### Let's check the distribution and outliers for each column in the data

# %% [markdown]
# #### Question 2:
# - **Create the histogram to check distribution of all variables (use .hist() attribute) (1 Mark)**
# - **Create boxplot to visualize outliers for all variables (use sns.boxplot()) (1 Mark)**
# - **Write your observations (2 Marks)**

# %%
# Uncomment and complete the code by filling the blanks 

for col in data.columns:
    print(col)
    print('Skew :',round(data[col].skew(),2))
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    data[col].hist()
    plt.ylabel('count')
    plt.subplot(1,2,2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# mpg
# Skew : 0.46
# cylinders
# Skew : 0.53
# displacement
# Skew : 0.72
# horsepower
# Skew : 1.11
# weight
# Skew : 0.53
# acceleration
# Skew : 0.28
# model year
# Skew : 0.01

# %% [markdown]
# **Observations:_____________**
# - mpg is skewed to the right with the median around 23. A couple of outliers on the box plot to the right greater than 45.
# - cylinders are discrete and distributed most frequently at 4 and moderately frequent at 6 and 8.
# - displacement is strongly skewed to the right with a median of 150. It has a maximum range of 1.5 IQR a little greater than 450.
# - horsepower is strongly skewed to the right and has many 7 outliers on the right past 190.
# - weight is skewed to the right and has a median around 2800 with 75% of the values falling in between ~2200 and ~3600.
# - acceleration is only slightly right skewed showing an almost normal distribution. It has a narrow IQR and a few outliers (2 on hte left and 4 on the right).
# - model year has a median at 76, minimum at 70, and maximum at 82.

# %% [markdown]
# #### Checking correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# **Observations:**
# - The variable mpg has strong negative correlation with cylinders, displacement, horsepower, and weight.
# - horsepower and acceleration are negatively correlated.
# - The variable weight has strong positively correlation with horsepower, displacement and cylinders
# - model year is positively correlated with mpg.

# %% [markdown]
# #### Scaling the data

# %%
# scaling the data
scaler=StandardScaler()
data_scaled=pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
data_scaled.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -0.706439   1.498191      1.090604    0.673118  0.630870     -1.295498
# 1 -1.090751   1.498191      1.503514    1.589958  0.854333     -1.477038
# 2 -0.706439   1.498191      1.196232    1.197027  0.550470     -1.658577
# 3 -0.962647   1.498191      1.061796    1.197027  0.546923     -1.295498
# 4 -0.834543   1.498191      1.042591    0.935072  0.565841     -1.840117
#
#    model year
# 0   -1.627426
# 1   -1.627426
# 2   -1.627426
# 3   -1.627426
# 4   -1.627426

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# #### Question 3:
#
# - **Apply the PCA algorithm with number of components equal to the total number of columns in the data with random_state=1 (2 Marks)**
# - **Write observations on the variance explained by components (2 Marks)**

# %%
#Defining the number of principal components to generate 
n=data_scaled.shape[1]

#Finding principal components for the data
pca = PCA(n_components=n, random_state=1) #Apply the PCA algorithm with random state = 1
data_pca1 = pd.DataFrame(pca.fit_transform(data_scaled)) #Fit and transform the pca function on scaled data

#The percentage of variance explained by each principal component
exp_var = pca.explained_variance_ratio_

# %%
# visualize the explained variance by individual components
plt.figure(figsize = (10,10))
plt.plot(range(1,8), exp_var.cumsum(), marker = 'o', linestyle = '--')
plt.title("Explained Variances by Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
# find the least number of components that can explain more than 90% variance
sum = 0
for ix, i in enumerate(exp_var):
  sum = sum + i
  if(sum>0.90):
    print("Number of PCs that explain at least 90% variance: ", ix+1)
    break
# Out:
# Number of PCs that explain at least 90% variance:  3

# %% [markdown]
# **Observations:**
#
# Each component is a dot on the line plot above. The first 3 components on the graph have the greatest amount of variance. These three components can now be visualized to check for clusters or outliers with the data. The other 4 components with low variance are not interesting for this exploratory analysis.

# %%
pc_comps = ['PC1','PC2','PC3']
data_pca = pd.DataFrame(np.round(pca.components_[:3,:],2),index=pc_comps,columns=data_scaled.columns)
data_pca.T
# Out:
#                PC1   PC2   PC3
# mpg          -0.40 -0.21 -0.26
# cylinders     0.42 -0.19  0.14
# displacement  0.43 -0.18  0.10
# horsepower    0.42 -0.09 -0.17
# weight        0.41 -0.22  0.28
# acceleration -0.28  0.02  0.89
# model year   -0.23 -0.91 -0.02

# %% [markdown]
# #### Question 4: **Interpret the coefficients of three principal components from the below dataframe (6 Marks)**

# %%
def color_high(val):
    if val <= -0.40: # you can decide any value as per your understanding
        return 'background: red'
    elif val >= 0.40:
        return 'background: blue'   
    
data_pca.T.style.applymap(color_high)
# Out:
# <style type="text/css">
# #T_b5c6c_row0_col0, #T_b5c6c_row6_col1 {
#   background: red;
# }
# #T_b5c6c_row1_col0, #T_b5c6c_row2_col0, #T_b5c6c_row3_col0, #T_b5c6c_row4_col0, #T_b5c6c_row5_col2 {
#   background: blue;
# }
# </style>
# <table id="T_b5c6c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PC1</th>
#       <th class="col_heading level0 col1" >PC2</th>
#       <th class="col_heading level0 col2" >PC3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5c6c_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_b5c6c_row0_col0" class="data row0 col0" >-0.400000</td>
#       <td id="T_b5c6c_row0_col1" class="data row0 col1" >-0.210000</td>
#       <td id="T_b5c6c_row0_col2" class="data row0 col2" >-0.260000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_b5c6c_row1_col0" class="data row1 col0" >0.420000</td>
#       <td id="T_b5c6c_row1_col1" class="data row1 col1" >-0.190000</td>
#       <td id="T_b5c6c_row1_col2" class="data row1 col2" >0.140000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_b5c6c_row2_col0" class="data row2 col0" >0.430000</td>
#       <td id="T_b5c6c_row2_col1" class="data row2 col1" >-0.180000</td>
#       <td id="T_b5c6c_row2_col2" class="data row2 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row3" class="row_heading level0 row3" >horsepower</th>
#       <td id="T_b5c6c_row3_col0" class="data row3 col0" >0.420000</td>
#       <td id="T_b5c6c_row3_col1" class="data row3 col1" >-0.090000</td>
#       <td id="T_b5c6c_row3_col2" class="data row3 col2" >-0.170000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row4" class="row_heading level0 row4" >weight</th>
#       <td id="T_b5c6c_row4_col0" class="data row4 col0" >0.410000</td>
#       <td id="T_b5c6c_row4_col1" class="data row4 col1" >-0.220000</td>
#       <td id="T_b5c6c_row4_col2" class="data row4 col2" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row5" class="row_heading level0 row5" >acceleration</th>
#       <td id="T_b5c6c_row5_col0" class="data row5 col0" >-0.280000</td>
#       <td id="T_b5c6c_row5_col1" class="data row5 col1" >0.020000</td>
#       <td id="T_b5c6c_row5_col2" class="data row5 col2" >0.890000</td>
#     </tr>
#     <tr>
#       <th id="T_b5c6c_level0_row6" class="row_heading level0 row6" >model year</th>
#       <td id="T_b5c6c_row6_col0" class="data row6 col0" >-0.230000</td>
#       <td id="T_b5c6c_row6_col1" class="data row6 col1" >-0.910000</td>
#       <td id="T_b5c6c_row6_col2" class="data row6 col2" >-0.020000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observations:__________________**
#
# Cylinders, mpg, displacement, horsepower, and weight are related to PC1.The column mpg is negatively correlated with PC1 and the other PC1 variation related columns are positively correlated -- when cylinders, displacement, horsepower, or weight increase, the auto is less fuel efficient. For PC2, the model year has the highest weight on this component's variance. For PC3, acceleration has the highest weight on this component's variance.

# %% [markdown]
# #### We can also visualize the data in 2 dimensions using first two principal components

# %%
plt.figure(figsize = (7,7))
sns.scatterplot(x=data_pca1[0],y=data_pca1[1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# **Let's try adding hue to the scatter plot**

# %% [markdown]
# #### Question 5:
#
# - **Create a scatter plot for first two principal components with hue = 'cylinders' (2 Marks)**
# - **Write your observations on the plot (2 Marks)**

# %%
df_concat = pd.concat([data_pca1, data], axis=1)

plt.figure(figsize = (7,7))
#Create a scatter plot with x=0 and y=1 using df_concat dataframe
sns.scatterplot(x = df_concat[0], y = df_concat[1], hue=df_concat['cylinders'])
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %% [markdown]
# **Observations:**
#
# The clustering of different autos on the principal component scatter plot can be explained by the number of cylinders.
# Since the cylinder ranges on the PC1 access from minimum to maximum that also indicates that this is the main difference between groups since spread on PC1 is more important than spread on PC2.

# %% [markdown]
# ## t-SNE

# %% [markdown]
# #### Question 6:
# - **Apply the TSNE embedding with 2 components for the dataframe data_scaled (use random_state=1) (2 Marks)**
# - **Write your observations on the below scatter plots (2 Marks)**

# %%
tsne = TSNE(n_components = 2, random_state=1)  #Apply the TSNE algorithm with random state = 1
data_tsne = tsne.fit_transform(data_scaled) #Fit and transform tsne function on the scaled data

# %%
data_tsne.shape
# Out:
# (398, 2)

# %%
data_tsne = pd.DataFrame(data = data_tsne, columns = ['Component 1', 'Component 2'])

# %%
data_tsne.head()
# Out:
#    Component 1  Component 2
# 0   -38.088413   -15.912958
# 1   -37.404369   -17.995850
# 2   -38.050472   -17.063194
# 3   -37.718334   -16.476006
# 4   -38.404663   -16.763493

# %%
sns.scatterplot(x=data_tsne.iloc[:,0],y=data_tsne.iloc[:,1])

# %%
# Let's see scatter plot of the data w.r.t number of cylinders
sns.scatterplot(x=data_tsne.iloc[:,0],y=data_tsne.iloc[:,1],hue=data.cylinders)

# %% [markdown]
# **Observations:**
#
# - There are three groups in the data. Each group has different number of cylinders. PC1 ranges with the lowest mpg on the left and highest on the right.
#
# - The group with mostly four cylinders are the most fuel-efficient and the group with the highest amount of cylinders of eight is the least fuel-efficient.

# %%
# Let's assign points to 3 different groups
def grouping(x):
    first_component = x['Component 1']
    second_component = x['Component 2']
    if (first_component> 0) and (second_component >0): 
        return 'group_1'
    if (first_component >-20 ) and (first_component < 5):
        return 'group_2'
    else: 
        return 'group_3'

# %%
data_tsne['groups'] = data_tsne.apply(grouping,axis=1)

# %%
sns.scatterplot(x=data_tsne.iloc[:,0],y=data_tsne.iloc[:,1],hue=data_tsne.iloc[:,2])
# Out:
# <AxesSubplot:xlabel='Component 1', ylabel='Component 2'>

# %%
data['groups'] = data_tsne['groups']

# %% [markdown]
# #### Question 7:
# - **Complete the following code by filling the blanks (2 Marks)**
# - **Write your observations on different groups w.r.t different variables (4 Marks)**

# %%
all_col = data.columns.tolist()
plt.figure(figsize=(20, 20))

for i, variable in enumerate(all_col):
    if i==7:
        break
    plt.subplot(4, 2, i + 1)
    #Create boxplot with groups on the x-axis and variable on the y-axis (use the dataframe data)
    sns.boxplot(y=data[variable], x=data['groups'])
    plt.tight_layout()
    plt.title(variable)
plt.show()

# %% [markdown]
# **Observations:**
#
# The box plots on cylinders show Group 1 has the least number at four and Group 3 has the most number at eight. The cylinders box plot also shows that there are very few autos that are not equal to four, six, and eight. There are two cars with more than four cylinders in Group 1, one auto at five cylinders and one auto at six cylinders, the higher fuel efficiency would be explained by other factors -- probably weight.
#
# Other box plots show that Group 1 also had lower displacement, horsepower, and weight which helps explain the better fuel efficiency of these autos. Group 1 also has newer model autos. Group 3 has high acceleration and that is a major factor on why these autos have the least amount of fuel economy.
